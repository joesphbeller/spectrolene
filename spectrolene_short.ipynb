# %%
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import ShortTermFeatures
import matplotlib.pyplot as plt
# Out:
# /Users/josephbeller/opt/anaconda3/lib/python3.8/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
#F, f_names = ShortTermFeatures.feature_extraction(x, Fs, Fs, Fs)
#plt.plot(F[3,:])
def chroma(filename):
    Fs, x = audioBasicIO.read_audio_file("data/" + filename)
    ShortTermFeatures.chromagram(x, Fs, 0.01*Fs, 0.01*Fs,plot=1,show_progress=1)

# %%
chroma("01_mono.wav")
# Out:
# 100%|██████████| 16326/16326 [00:07<00:00, 2091.23it/s]

# %%
chroma("02_mono.wav")
# Out:
# 100%|██████████| 12700/12700 [00:06<00:00, 1851.78it/s]

# %%
chroma("03_mono.wav")
# Out:
# 100%|██████████| 14029/14029 [00:08<00:00, 1584.24it/s]

# %%
ShortTermFeatures.feature_extraction?
